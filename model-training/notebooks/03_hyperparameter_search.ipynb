# %% [markdown]
# #### Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from evaluation import UnlabeledEvaluator
from settings import HYPERPARAM_SEARCH_SPACE, MODEL_PATH

# %%
video_path_str = "E:/01_personal_project/input/square_video/20251115 18s00000264.mp4"
folder_path_str = "E:/01_personal_project/input/square_video/select/"

# %% [markdown]
# Changes:
# - Check that a model exists at that location, if not raise an error before starting ANY experiment
# - Save the name of the model, not the path to mlflow

# %%
evaluator = UnlabeledEvaluator(model_path=MODEL_PATH)
evaluator.search(search_space_config=HYPERPARAM_SEARCH_SPACE, path=video_path_str)
# Out:
# 2026-01-29 15:51:34.234 | INFO     | evaluation.unlabeled_evaluator:search:594 - Starting search with 16 parameter combinations
# 2026-01-29 15:51:34.235 | INFO     | evaluation.unlabeled_evaluator:search:601 - Experiment 1/16
# 2026-01-29 15:51:34.292 | INFO     | evaluation.unlabeled_evaluator:_process_single_video:162 - Processing video: E:\01_personal_project\input\square_video\20251115 18s00000264.mp4
# 2026-01-29 15:51:34.317 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 0
# 2026-01-29 15:51:49.966 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 500
# 2026-01-29 15:51:50.325 | INFO     | evaluation.unlabeled_evaluator:evaluate_single_video:229 - Computing metrics...
# 2026-01-29 15:51:50.326 | SUCCESS  | evaluation.unlabeled_evaluator:evaluate_single_video:231 - Metrics calculated
# ...

# %%
# cd model-training
# mlflow ui --backend-store-uri file:output/mlruns
# http://localhost:5000/ in browser

# %%
# Good Performance:

# High confidence (>0.7)
# Long, stable tracks
# Low jitter (<10 pixels)
# Few short tracks (<20%)
# Consistent detections per frame
# Poor Performance:

# Low confidence (<0.5)
# Many short, fragmented tracks
# High jitter (>30 pixels)
# Erratic detections per frame
# High short track ratio (>50%)
