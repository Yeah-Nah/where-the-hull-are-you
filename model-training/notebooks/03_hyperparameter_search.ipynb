# %% [markdown]
# #### Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path
import pandas as pd
from itertools import product

from loguru import logger

sys.path.append(str(Path.cwd().parent / "src"))

from config.model_settings import MODEL_CONFIG, HYPERPARAM_SEARCH_SPACE, MODEL_PATH
from evaluation.unlabeled_evaluator import UnlabeledEvaluator

# %%
import sys
del sys.modules['config.model_settings']  # Force module reload
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[112], line 2
#       1 import sys
# ----> 2 del sys.modules['config.model_settings']  # Force module reload
#
# KeyError: 'config.model_settings'

# %%
video_path_str = "E:/01_personal_project/input/preprocessed/20251026_155528.mp4"
folder_path_str = "E:/01_personal_project/input/square_video/select/"

# %%
evaluator = UnlabeledEvaluator(model_path=MODEL_PATH)

# %%
HYPERPARAM_SEARCH_SPACE
# Out:
# {'conf': [0.4, 0.7],
#  'classes': [8],
#  'persist': [True],
#  'verbose': [False],
#  'tracker_type': ['botsort'],
#  'track_high_thresh': [0.1, 0.25],
#  'track_low_thresh': [0.1],
#  'new_track_thresh': [0.1, 0.25],
#  'track_buffer': [15, 30],
#  'match_thresh': [0.5],
#  'fuse_score': [True],
#  'gmc_method': ['sparseOptFlow'],
#  'proximity_thresh': [0.5],
#  'appearance_thresh': [0.5],
#  'with_reid': [False],
#  'model': ['auto']}

# %%
evaluator.search(search_space_config=HYPERPARAM_SEARCH_SPACE, path=video_path_str)
# Out:
# 2026-01-23 22:09:38.058 | INFO     | evaluation.unlabeled_evaluator:search:24 - Starting hyperparameter search on single video file.
# 2026-01-23 22:09:38.078 | INFO     | evaluation.unlabeled_evaluator:_process_single_video:19 - Processing video: E:\01_personal_project\input\preprocessed\20251026_155528.mp4
# 2026-01-23 22:09:38.089 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:36 - Processed frame 0
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[117], line 1
# ----> 1 evaluator.search(search_space_config=HYPERPARAM_SEARCH_SPACE, path=video_path_str)
#
# File c:\Users\alexa\git\where-the-hull-are-you\model-training\src\evaluation\unlabeled_evaluator.py:25, in search(self, search_space_config, path)
#      24 self.model_path = model_path
# ---> 25 self.collector = TrackingMetricsCollector()
#      26 self.calculator = MetricsCalculator(self.collector)
#
# File c:\Users\alexa\git\where-the-hull-are-you\model-training\src\evaluation\unlabeled_evaluator.py:22, in evaluate_single_video(self, video_path, model_config, batch_size)
#      16 def __init__(self, model_path: Path):
#      17     """Initialize evaluator with model.
#      18
#      19     Parameters
#      20     ----------
#      21     model_path : Path
# ---> 22         Path to model weights
#      23     """
#      24     self.model_path = model_path
#
# File c:\Users\alexa\git\where-the-hull-are-you\model-training\src\evaluation\unlabeled_evaluator.py:29, in _process_single_video(self, video_path, inference, frame_batch_size)
#      28 def _create_inference(self, model_config) -> ModelInference:
# ---> 29     """Create model infernce for given config.
#      30
#      31     Parameters
#      32     ----------
#      33     model_config : config
#      34         Model config
#      35
#      36     Returns
#      37     -------
#      38     ModelInference
#      39         Configured inference instance
#      40     """
#      42     return ModelInference(
#      43         model_path=str(self.model_path),
#      44         model_config=model_config
#      45     )
#
# File ~\git\where-the-hull-are-you\shared-tracking-metrics\src\tracking_metrics\inference.py:88, in ModelInference.predict_batch_frames(self, frames)
#      76 """Run YOLO on multiple frames at once.
#      77
#      78 Parameters
#    (...)     86     Detections for each frame
#      87 """
# ---> 88 results = self.model.track(frames, **self.model_kwargs)
#      90 all_detections = []
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\ultralytics\engine\model.py:601, in Model.track(self, source, stream, persist, **kwargs)
#     600 kwargs["mode"] = "track"
# --> 601 return self.predict(source=source, stream=stream, **kwargs)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\ultralytics\engine\model.py:549, in Model.predict(self, source, stream, predictor, **kwargs)
#     548 if not self.predictor:
# --> 549     self.predictor = (predictor or self._smart_load("predictor"))(overrides=args, _callbacks=self.callbacks)
#     550     self.predictor.setup_model(model=self.model, verbose=is_cli)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\ultralytics\engine\predictor.py:126, in BasePredictor.__init__(self, cfg, overrides, _callbacks)
#     118 """
#     119 Initialize the BasePredictor class.
#     120
#    (...)    124     _callbacks (dict, optional): Dictionary of callback functions.
#     125 """
# --> 126 self.args = get_cfg(cfg, overrides)
#     127 self.save_dir = get_save_dir(self.args)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\ultralytics\cfg\__init__.py:311, in get_cfg(cfg, overrides)
#     310     overrides.pop("save_dir", None)  # special override keys to ignore
# --> 311 check_dict_alignment(cfg, overrides)
#     312 cfg = {**cfg, **overrides}  # merge cfg and overrides dicts (prefer overrides)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\ultralytics\cfg\__init__.py:504, in check_dict_alignment(base, custom, e)
#     503     string += f"'{colorstr('red', 'bold', x)}' is not a valid YOLO argument. {match_str}\n"
# --> 504 raise SyntaxError(string + CLI_HELP_MSG) from e
#
# SyntaxError: 'appearance_thresh' is not a valid YOLO argument.
# 'track_high_thresh' is not a valid YOLO argument.
# 'track_buffer' is not a valid YOLO argument. Similar arguments are i.e. ['stream_buffer=False', 'tracker=botsort.yaml'].
# 'fuse_score' is not a valid YOLO argument.
# 'tracker_type' is not a valid YOLO argument. Similar arguments are i.e. ['tracker=botsort.yaml'].
# 'with_reid' is not a valid YOLO argument.
# 'track_low_thresh' is not a valid YOLO argument.
# 'match_thresh' is not a valid YOLO argument.
# 'proximity_thresh' is not a valid YOLO argument.
# 'new_track_thresh' is not a valid YOLO argument.
# 'gmc_method' is not a valid YOLO argument.
#
#     Arguments received: ['yolo', '--f=c:\\Users\\alexa\\AppData\\Roaming\\jupyter\\runtime\\kernel-v3620c108b30e904a49925b695f6acb6e29dbbadf2.json']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['segment', 'detect', 'obb', 'classify', 'pose']
#                 MODE (required) is one of ['train', 'predict', 'benchmark', 'export', 'val', 'track']
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco8.yaml model=yolo11n.pt epochs=10 lr0=0.01
#
#     2. Predict a YouTube video using a pretrained segmentation model at image size 320:
#         yolo predict model=yolo11n-seg.pt source='https://youtu.be/LNwODJXcvt4' imgsz=320
#
#     3. Val a pretrained detection model at batch-size 1 and image size 640:
#         yolo val model=yolo11n.pt data=coco8.yaml batch=1 imgsz=640
#
#     4. Export a YOLO11n classification model to ONNX format at image size 224 by 128 (no TASK required)
#         yolo export model=yolo11n-cls.pt format=onnx imgsz=224,128
#
#     5. Ultralytics solutions usage
#         yolo solutions count or in ['crop', 'blur', 'workout', 'heatmap', 'isegment', 'visioneye', 'speed', 'queue', 'analytics', 'inference', 'trackzone'] source="path/to/video.mp4"
#
#     6. Run special commands:
#         yolo help
#         yolo checks
#         yolo version
#         yolo settings
#         yolo copy-cfg
#         yolo cfg
#         yolo solutions help
#
#     Docs: https://docs.ultralytics.com
#     Solutions: https://docs.ultralytics.com/solutions/
#     Community: https://community.ultralytics.com
#     GitHub: https://github.com/ultralytics/ultralytics
#      (<string>)
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\interactiveshell.py:2164, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2159     return
#    2161 if issubclass(etype, SyntaxError):
#    2162     # Though this won't be called by syntax errors in the input
#    2163     # line, there may be SyntaxError cases with imported code.
# -> 2164     self.showsyntaxerror(filename, running_compiled_code)
#    2165 elif etype is UsageError:
#    2166     self.show_usage_error(value)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\interactiveshell.py:2254, in InteractiveShell.showsyntaxerror(self, filename, running_compiled_code)
#    2252 # If the error occurred when executing compiled code, we should provide full stacktrace.
#    2253 elist = traceback.extract_tb(last_traceback) if running_compiled_code else []
# -> 2254 stb = self.SyntaxTB.structured_traceback(etype, value, elist)
#    2255 self._showtraceback(etype, value, stb)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\ultratb.py:1243, in SyntaxTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1241         value.text = newtext
#    1242 self.last_syntax_error = value
# -> 1243 return super(SyntaxTB, self).structured_traceback(
#    1244     etype, value, etb, tb_offset=tb_offset, context=context
#    1245 )
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\ultratb.py:212, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     210     out_list.extend(self._format_list(elist))
#     211 # The exception info should be a single entry in the list.
# --> 212 lines = "".join(self._format_exception_only(etype, evalue))
#     213 out_list.append(lines)
#     215 # Find chained exceptions if we have a traceback (not for exception-only mode)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\ultratb.py:341, in ListTB._format_exception_only(self, etype, value)
#     327 output_list.append(
#     328     theme_table[self._theme_name].format(
#     329         [(Token, "  ")]
#    (...)    336     )
#     337 )
#     338 if textline == "":
#     339     # sep 2025:
#     340     # textline = py3compat.cast_unicode(value.text, "utf-8")
# --> 341     assert isinstance(value.text, str)
#     342     textline = value.text
#     344 if textline is not None:
#
# AssertionError:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\async_helpers.py:128, in _pseudo_sync_runner(coro)
#     120 """
#     121 A runner that does not really allow async execution, and just advance the coroutine.
#     122
#    (...)    125 Credit to Nathaniel Smith
#     126 """
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#     130     return exc.value
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\interactiveshell.py:3413, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3409 exec_count = self.execution_count
#    3410 if result.error_in_exec:
#    3411     # Store formatted traceback and error details
#    3412     self.history_manager.exceptions[exec_count] = (
# -> 3413         self._format_exception_for_storage(result.error_in_exec)
#    3414     )
#    3416 # Each cell is a *single* input, regardless of how many lines it has
#    3417 self.execution_count += 1
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\interactiveshell.py:3442, in InteractiveShell._format_exception_for_storage(self, exception, filename, running_compiled_code)
#    3440     # Extract traceback if the error happened during compiled code execution
#    3441     elist = traceback.extract_tb(tb) if running_compiled_code else []
# -> 3442     stb = self.SyntaxTB.structured_traceback(etype, evalue, elist)
#    3444 # Handle UsageError with a simple message
#    3445 elif etype is UsageError:
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\ultratb.py:1243, in SyntaxTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1241         value.text = newtext
#    1242 self.last_syntax_error = value
# -> 1243 return super(SyntaxTB, self).structured_traceback(
#    1244     etype, value, etb, tb_offset=tb_offset, context=context
#    1245 )
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\ultratb.py:212, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     210     out_list.extend(self._format_list(elist))
#     211 # The exception info should be a single entry in the list.
# --> 212 lines = "".join(self._format_exception_only(etype, evalue))
#     213 out_list.append(lines)
#     215 # Find chained exceptions if we have a traceback (not for exception-only mode)
#
# File c:\Users\alexa\anaconda3\envs\where-the-hull-are-you\Lib\site-packages\IPython\core\ultratb.py:341, in ListTB._format_exception_only(self, etype, value)
#     327 output_list.append(
#     328     theme_table[self._theme_name].format(
#     329         [(Token, "  ")]
#    (...)    336     )
#     337 )
#     338 if textline == "":
#     339     # sep 2025:
#     340     # textline = py3compat.cast_unicode(value.text, "utf-8")
# --> 341     assert isinstance(value.text, str)
#     342     textline = value.text
#     344 if textline is not None:
#
# AssertionError:
