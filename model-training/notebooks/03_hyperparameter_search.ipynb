# %% [markdown]
# #### Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from config.model_settings import HYPERPARAM_SEARCH_SPACE, MODEL_PATH
from evaluation.unlabeled_evaluator import UnlabeledEvaluator

# %%
import os
from pathlib import Path

# Use environment variable or default to project-relative path
base_input_dir = Path(
    os.environ.get("INPUT_BASE_DIR", Path.cwd().parent.parent / "input")
)
video_path_str = str(base_input_dir / "preprocessed" / "20251026_155528.mp4")
folder_path_str = str(base_input_dir / "square_video" / "select")

# %%
evaluator = UnlabeledEvaluator(model_path=MODEL_PATH)
evaluator.search(search_space_config=HYPERPARAM_SEARCH_SPACE, path=video_path_str)
