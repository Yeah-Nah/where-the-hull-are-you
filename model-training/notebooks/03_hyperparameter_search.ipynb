# %% [markdown]
# #### Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

del sys.modules["config.model_settings"]

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from config.model_settings import HYPERPARAM_SEARCH_SPACE
from evaluation.unlabeled_evaluator import UnlabeledEvaluator

# %%
video_path_str = "E:/01_personal_project/input/square_video/20251115 18s00000264.mp4"
folder_path_str = "E:/01_personal_project/input/square_video/select/"

# %%
model_path = "C:/Users/alexa/git/where-the-hull-are-you/model-training/models/yolov8n_openvino_2022.1_6shave.blob"

# %%
evaluator = UnlabeledEvaluator(model_path=model_path)
evaluator.search(search_space_config=HYPERPARAM_SEARCH_SPACE, path=video_path_str)
# Out:
# 2026-01-25 14:55:06.472 | INFO     | evaluation.unlabeled_evaluator:search:591 - Starting search with 3 parameter combinations
# 2026-01-25 14:55:06.473 | INFO     | evaluation.unlabeled_evaluator:search:598 - Experiment 1/3
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# 2026-01-25 14:55:06.514 | INFO     | evaluation.unlabeled_evaluator:_process_single_video:162 - Processing video: E:\01_personal_project\input\square_video\20251115 18s00000264.mp4
# 2026-01-25 14:55:06.539 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 0
# ...

# %%
# cd model-training
# mlflow ui --backend-store-uri file:output/mlruns
# http://localhost:5000/ in browser
