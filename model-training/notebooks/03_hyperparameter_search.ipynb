# %% [markdown]
# #### Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys

del sys.modules["config.model_settings"]

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from config.model_settings import HYPERPARAM_SEARCH_SPACE, MODEL_PATH
from evaluation.unlabeled_evaluator import UnlabeledEvaluator

# %%
video_path_str = "E:/01_personal_project/input/square_video/20251115 18s00000264.mp4"
folder_path_str = "E:/01_personal_project/input/square_video/select/"

# %%
evaluator = UnlabeledEvaluator(model_path=MODEL_PATH)
evaluator.search(search_space_config=HYPERPARAM_SEARCH_SPACE, path=video_path_str)
# Out:
# 2026-01-25 12:13:20.910 | INFO     | evaluation.unlabeled_evaluator:search:591 - Starting search with 3 parameter combinations
# 2026-01-25 12:13:20.911 | INFO     | evaluation.unlabeled_evaluator:search:598 - Experiment 1/3
# 2026-01-25 12:13:20.972 | INFO     | evaluation.unlabeled_evaluator:_process_single_video:162 - Processing video: E:\01_personal_project\input\square_video\20251115 18s00000264.mp4
# 2026-01-25 12:13:21.003 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 0
# 2026-01-25 12:13:36.901 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 500
# 2026-01-25 12:13:37.229 | INFO     | evaluation.unlabeled_evaluator:evaluate_single_video:229 - Computing metrics...
# 2026-01-25 12:13:37.231 | SUCCESS  | evaluation.unlabeled_evaluator:evaluate_single_video:231 - Metrics calculated
# 2026-01-25 12:13:37.241 | SUCCESS  | evaluation.unlabeled_evaluator:_run_single_experiment:529 - Logged experiment 0
# 2026-01-25 12:13:37.244 | INFO     | evaluation.unlabeled_evaluator:search:598 - Experiment 2/3
# 2026-01-25 12:13:37.297 | INFO     | evaluation.unlabeled_evaluator:_process_single_video:162 - Processing video: E:\01_personal_project\input\square_video\20251115 18s00000264.mp4
# 2026-01-25 12:13:37.320 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 0
# 2026-01-25 12:13:52.572 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 500
# 2026-01-25 12:13:52.913 | INFO     | evaluation.unlabeled_evaluator:evaluate_single_video:229 - Computing metrics...
# 2026-01-25 12:13:52.915 | SUCCESS  | evaluation.unlabeled_evaluator:evaluate_single_video:231 - Metrics calculated
# 2026-01-25 12:13:52.937 | SUCCESS  | evaluation.unlabeled_evaluator:_run_single_experiment:529 - Logged experiment 1
# 2026-01-25 12:13:52.941 | INFO     | evaluation.unlabeled_evaluator:search:598 - Experiment 3/3
# 2026-01-25 12:13:52.994 | INFO     | evaluation.unlabeled_evaluator:_process_single_video:162 - Processing video: E:\01_personal_project\input\square_video\20251115 18s00000264.mp4
# 2026-01-25 12:13:53.018 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 0
# 2026-01-25 12:14:08.697 | DEBUG    | evaluation.unlabeled_evaluator:_process_single_video:185 - Processed frame 500
# 2026-01-25 12:14:09.043 | INFO     | evaluation.unlabeled_evaluator:evaluate_single_video:229 - Computing metrics...
# 2026-01-25 12:14:09.045 | SUCCESS  | evaluation.unlabeled_evaluator:evaluate_single_video:231 - Metrics calculated
# 2026-01-25 12:14:09.057 | SUCCESS  | evaluation.unlabeled_evaluator:_run_single_experiment:529 - Logged experiment 2
# 2026-01-25 12:14:09.060 | SUCCESS  | evaluation.unlabeled_evaluator:search:605 - Completed 3 experiments

# %%
# cd model-training
# mlflow ui --backend-store-uri file:output/mlruns
# http://localhost:5000/ in browser
