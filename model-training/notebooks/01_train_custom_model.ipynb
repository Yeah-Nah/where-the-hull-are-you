# %% [markdown]
# ## Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from settings import TRAINING_CONFIG
from training.trainer import ModelTrainer

# %%
from utils import reload_module

reload_module("ModelTrainer")
reload_module("settings")
# Out:
# 2026-02-09 22:46:47.230 | SUCCESS  | utils.notebook_utils:reload_module:19 - Module ModelTrainer unloaded.
# 2026-02-09 22:46:47.231 | INFO     | utils.notebook_utils:reload_module:20 - Please reload ModelTrainer to apply changes.
# 2026-02-09 22:46:47.231 | SUCCESS  | utils.notebook_utils:reload_module:19 - Module settings unloaded.
# 2026-02-09 22:46:47.232 | INFO     | utils.notebook_utils:reload_module:20 - Please reload settings to apply changes.

# %%
trainer = ModelTrainer(training_config=TRAINING_CONFIG)
best_weights = trainer.train()
# Out:
# 2026-02-09 22:47:24.102 | SUCCESS  | training.trainer:_load_base_model:18 - Base model loaded: c:\Users\alexa\git\where-the-hull-are-you\model-training\models\yolov8n.pt
# 2026-02-09 22:47:24.126 | INFO     | training.trainer:_create_data_yaml:24 - Created data.yaml at: c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml
# 2026-02-09 22:47:24.127 | INFO     | training.trainer:train:11 -
# Starting training with configuration:
# 2026-02-09 22:47:24.127 | INFO     | training.trainer:train:13 -   data: c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml
# 2026-02-09 22:47:24.128 | INFO     | training.trainer:train:13 -   name: 18ft_skiff_v1_20260209_224724
# 2026-02-09 22:47:24.128 | INFO     | training.trainer:train:13 -   model: yolov8n.pt
# 2026-02-09 22:47:24.128 | INFO     | training.trainer:train:13 -   epochs: 50
# 2026-02-09 22:47:24.129 | INFO     | training.trainer:train:13 -   batch: 16
# 2026-02-09 22:47:24.129 | INFO     | training.trainer:train:13 -   imgsz: 640
# 2026-02-09 22:47:24.129 | INFO     | training.trainer:train:13 -   lr0: 0.01
# 2026-02-09 22:47:24.131 | INFO     | training.trainer:train:13 -   rect: True
# 2026-02-09 22:47:24.132 | INFO     | training.trainer:train:13 -   classes: [0]
# 2026-02-09 22:47:24.133 | INFO     | training.trainer:train:13 -   exist_ok: True
# New https://pypi.org/project/ultralytics/8.4.13 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.13.11 torch-2.10.0+cpu CPU (13th Gen Intel Core i7-13700K)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=[0], close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=18ft_skiff_v1_20260209_224724, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=True, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 2216.9137.6 MB/s, size: 5443.5 KB)
# train: Scanning C:\Users\alexa\git\where-the-hull-are-you\model-training\data\labels.cache... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 34.5Mit/s 0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 3160.3552.6 MB/s, size: 5667.9 KB)
# val: Scanning C:\Users\alexa\git\where-the-hull-are-you\model-training\data\labels.cache... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 49.9Mit/s 0.0s
# Plotting labels to C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# MLflow: logging run_id(41767a7a7eb24f1da2bf15e9634b54f5) to runs\mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs\mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.566      3.614      1.462         23        384: 100% ━━━━━━━━━━━━ 7/7 1.9s/it 13.3s1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4s/it 9.5s4.4ss
#                    all        107        170     0.0118      0.912      0.488      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.307      2.638      1.285         13        384: 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6
0.799
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G     0.6789     0.7373      0.935         14        384: 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 8.9s4.1ss
#                    all        107        170       0.95      0.885      0.964      0.794
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G     0.6471     0.7302     0.9266         20        384: 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.6s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 9.0s4.1ss
#                    all        107        170      0.918      0.922      0.965      0.813
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.6364     0.7437     0.9343         13        384: 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4s/it 9.5s4.4ss
#                    all        107        170      0.938      0.929      0.967      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.6903     0.7487     0.9407         12        384: 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.1s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.3s4.2ss
#                    all        107        170      0.942      0.924      0.968      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G     0.6782      0.717     0.9304         15        384: 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 8.9s4.1ss
#                    all        107        170      0.969      0.888      0.971      0.826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.6264     0.6941     0.9143         12        384: 100% ━━━━━━━━━━━━ 7/7 1.2it/s 6.1s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 9.0s4.1ss
#                    all        107        170      0.928      0.941       0.98      0.835
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.6187     0.6703      0.889         25        384: 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.4s4.3ss
#                    all        107        170      0.934      0.947      0.983      0.842
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G     0.6384     0.6866     0.8985         17        384: 100% ━━━━━━━━━━━━ 7/7 1.0s/it 7.2s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.5s/it 9.8s4.5sss
#                    all        107        170       0.91      0.976      0.981      0.847
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.6175     0.7004     0.8961         17        384: 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.8s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.4s/it 9.6s4.4ss
#                    all        107        170      0.934      0.941      0.982      0.853
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.6018     0.6682     0.8877         14        384: 100% ━━━━━━━━━━━━ 7/7 1.0it/s 6.9s1.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 8.9s4.1ss
#                    all        107        170      0.958      0.933      0.985       0.86
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.5849     0.6546     0.9011         16        384: 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.2s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.2s4.2ss
#                    all        107        170      0.974      0.947      0.988      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.5634     0.6486     0.8949         13        384: 100% ━━━━━━━━━━━━ 7/7 1.3it/s 5.5s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.2s4.2ss
#                    all        107        170      0.975      0.953      0.988      0.868
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.5925     0.6421     0.8934         24        384: 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.0s4.1ss
#                    all        107        170      0.965      0.959      0.989      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.5307     0.6305     0.8949         17        384: 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.5s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.2s4.2ss
#                    all        107        170      0.966      0.965      0.989      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.5389     0.6122     0.8859         19        384: 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.3s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.4s4.3ss
#                    all        107        170      0.976      0.971       0.99      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.5652     0.6385     0.8817         18        384: 100% ━━━━━━━━━━━━ 7/7 1.1it/s 6.1s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.2s4.2ss
#                    all        107        170      0.975      0.971       0.99      0.869
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.5276     0.6168     0.8832         15        384: 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s0.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.1s4.1ss
#                    all        107        170       0.98      0.971      0.991      0.874
#
# 50 epochs completed in 0.217 hours.
# Optimizer stripped from C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724\weights\best.pt, 6.2MB
#
# Validating C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724\weights\best.pt...
# Ultralytics 8.4.12  Python-3.13.11 torch-2.10.0+cpu CPU (13th Gen Intel Core i7-13700K)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 8.9s4.0ss
#                    all        107        170      0.965      0.959      0.989      0.875
#             18ft skiff        105        170      0.965      0.959      0.989      0.875
# Speed: 0.3ms preprocess, 15.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_224724
# MLflow: results logged to runs\mlflow
# MLflow: disable with 'yolo settings mlflow=False'
# 2026-02-09 23:00:38.037 | SUCCESS  | training.trainer:train:15 - Training completed!

# %%
from ultralytics import YOLO
model = YOLO("c:/Users/alexa/git/where-the-hull-are-you/model-training/models/custom/best.pt")

# %%
for i in model.names:
    print(i)
# Out:
# 0
# 1
