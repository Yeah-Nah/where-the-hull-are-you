# %% [markdown]
# ## Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from settings import TRAINING_CONFIG
from training.trainer import ModelTrainer

# %%
from utils import reload_module

reload_module("ModelTrainer")
reload_module("settings")
# Out:
# 2026-02-10 12:59:11.345 | SUCCESS  | utils.notebook_utils:reload_module:19 - Module ModelTrainer unloaded.
# 2026-02-10 12:59:11.345 | INFO     | utils.notebook_utils:reload_module:20 - Please reload ModelTrainer to apply changes.
# 2026-02-10 12:59:11.345 | SUCCESS  | utils.notebook_utils:reload_module:19 - Module settings unloaded.
# 2026-02-10 12:59:11.346 | INFO     | utils.notebook_utils:reload_module:20 - Please reload settings to apply changes.

# %%
trainer = ModelTrainer(training_config=TRAINING_CONFIG)
best_weights = trainer.train()
# Out:
# 2026-02-10 12:59:48.499 | SUCCESS  | training.trainer:_load_base_model:18 - Base model loaded: c:\Users\alexa\git\where-the-hull-are-you\model-training\models\yolo11n.pt
# 2026-02-10 12:59:48.555 | INFO     | training.trainer:_create_data_yaml:24 - Created data.yaml at: c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml
# 2026-02-10 12:59:48.556 | INFO     | training.trainer:train:11 -
# Starting training with configuration:
# 2026-02-10 12:59:48.556 | INFO     | training.trainer:train:13 -   data: c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml
# 2026-02-10 12:59:48.557 | INFO     | training.trainer:train:13 -   name: 18ft_skiff_yolo11n_20260210_125948
# 2026-02-10 12:59:48.557 | INFO     | training.trainer:train:13 -   model: yolo11n.pt
# 2026-02-10 12:59:48.557 | INFO     | training.trainer:train:13 -   epochs: 100
# 2026-02-10 12:59:48.558 | INFO     | training.trainer:train:13 -   batch: 16
# ...

# %%
from ultralytics import YOLO

model = YOLO(
    "c:/Users/alexa/git/where-the-hull-are-you/model-training/models/custom/best.pt"
)

# %%
for i in model.names:
    print(i)
# Out:
# 0
# 1
