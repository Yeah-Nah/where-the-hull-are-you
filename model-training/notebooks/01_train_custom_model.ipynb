# %% [markdown]
# ## Setup and Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))

from settings import TRAINING_CONFIG
from training.trainer import ModelTrainer

# %%
TRAINING_CONFIG
# Out:
# {'training': {'model': 'yolov8n.pt',
#   'epochs': 2,
#   'batch': 16,
#   'imgsz': 640,
#   'lr0': 0.01,
#   'rect': True,
#   'classes': [0]},
#  'training_run_name': '18ft_skiff_v1',
#  'exist_ok': True}

# %%
from utils import reload_module

reload_module("ModelTrainer")
reload_module("settings")
# Out:
# 2026-02-09 22:19:58.797 | SUCCESS  | utils.notebook_utils:reload_module:19 - Module ModelTrainer unloaded.
# 2026-02-09 22:19:58.798 | INFO     | utils.notebook_utils:reload_module:20 - Please reload ModelTrainer to apply changes.
# 2026-02-09 22:19:58.798 | SUCCESS  | utils.notebook_utils:reload_module:19 - Module settings unloaded.
# 2026-02-09 22:19:58.798 | INFO     | utils.notebook_utils:reload_module:20 - Please reload settings to apply changes.

# %%
trainer = ModelTrainer(training_config=TRAINING_CONFIG)
best_weights = trainer.train()
print(f"Training complete! Best model: {best_weights}")
# Out:
# 2026-02-09 22:07:52.724 | SUCCESS  | training.trainer:_load_base_model:46 - Base model loaded: c:\Users\alexa\git\where-the-hull-are-you\model-training\models\yolov8n.pt
# 2026-02-09 22:07:52.745 | INFO     | training.trainer:_create_data_yaml:23 - Created data.yaml at: c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml
# 2026-02-09 22:07:52.745 | INFO     | training.trainer:train:11 -
# Starting training with configuration:
# 2026-02-09 22:07:52.746 | INFO     | training.trainer:train:13 -   data: c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml
# 2026-02-09 22:07:52.746 | INFO     | training.trainer:train:13 -   name: 18ft_skiff_v1_20260209_220752
# 2026-02-09 22:07:52.747 | INFO     | training.trainer:train:13 -   model: yolov8n.pt
# 2026-02-09 22:07:52.747 | INFO     | training.trainer:train:13 -   epochs: 2
# 2026-02-09 22:07:52.748 | INFO     | training.trainer:train:13 -   batch: 16
# 2026-02-09 22:07:52.748 | INFO     | training.trainer:train:13 -   imgsz: 640
# 2026-02-09 22:07:52.748 | INFO     | training.trainer:train:13 -   lr0: 0.01
# 2026-02-09 22:07:52.748 | INFO     | training.trainer:train:13 -   rect: True
# 2026-02-09 22:07:52.749 | INFO     | training.trainer:train:13 -   classes: [0]
# 2026-02-09 22:07:52.749 | INFO     | training.trainer:train:13 -   exist_ok: True
# New https://pypi.org/project/ultralytics/8.4.13 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.12  Python-3.13.11 torch-2.10.0+cpu CPU (13th Gen Intel Core i7-13700K)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=[0], close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\alexa\git\where-the-hull-are-you\model-training\data\data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=2, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=18ft_skiff_v1_20260209_220752, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=True, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.00.0 ms, read: 3194.0398.7 MB/s, size: 5443.5 KB)
# train: Scanning C:\Users\alexa\git\where-the-hull-are-you\model-training\data\labels.cache... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 40.8Mit/s 0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 2544.6412.5 MB/s, size: 5667.9 KB)
# val: Scanning C:\Users\alexa\git\where-the-hull-are-you\model-training\data\labels.cache... 107 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 107/107 49.9Mit/s 0.0s
# Plotting labels to C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# MLflow: logging run_id(0a3ed22f228a4bdd9bc2d7e2f2acbd30) to runs\mlflow
# MLflow: view at http://127.0.0.1:5000 with 'mlflow server --backend-store-uri runs\mlflow'
# MLflow: disable with 'yolo settings mlflow=False'
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752
# Starting training for 2 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/2         0G      1.566      3.614      1.462         23        384: 100% ━━━━━━━━━━━━ 7/7 1.9s/it 13.2s1.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.3s/it 9.2s4.2ss
#                    all        107        170     0.0118      0.912      0.488      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/2         0G        1.3      2.849      1.287         13        384: 100% ━━━━━━━━━━━━ 7/7 1.2it/s 5.9s0.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 9.0s4.1ss
#                    all        107        170     0.0109      0.947      0.607      0.361
#
# 2 epochs completed in 0.010 hours.
# Optimizer stripped from C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752\weights\best.pt, 6.2MB
#
# Validating C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752\weights\best.pt...
# Ultralytics 8.4.12  Python-3.13.11 torch-2.10.0+cpu CPU (13th Gen Intel Core i7-13700K)
# Model summary (fused): 73 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 2.2s/it 8.8s4.0ss
#                    all        107        170      0.011      0.947      0.606       0.36
#             18ft skiff        105        170      0.011      0.947      0.606       0.36
# Speed: 0.3ms preprocess, 13.2ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752
# MLflow: results logged to runs\mlflow
# MLflow: disable with 'yolo settings mlflow=False'
# 2026-02-09 22:08:41.449 | INFO     | training.trainer:train:18 -
# Training completed!
# 2026-02-09 22:08:41.449 | INFO     | training.trainer:train:19 - Best weights: C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752\weights\best.pt
# Training complete! Best model: C:\Users\alexa\git\where-the-hull-are-you\model-training\notebooks\runs\detect\18ft_skiff_v1_20260209_220752\weights\best.pt
